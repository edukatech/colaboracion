# %% [markdown]
# <a href="https://colab.research.google.com/github/luisjluna/colaboracion/blob/main/Comandos_Varios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comandos Varios

# %%
print ('Hola mundo,')
# Out:
# Hola mundo,

# %%
data_str = input('Introduce un número: ')
data=float(data_str)
if data > 100:
    print ('Tu número es mayor que 100')
elif data < 0:
    print ('Número negativo')
else :
    print ('Tu número está entre 0 y 100')
# Out:
# Introduce un número: 50
# Tu número está entre 0 y 100

# %%
while ((input !="s") and (input !="n")):
    input=input('Estas leyendo esto (s-n) ')
# Out:
# Estas leyendo esto (s-n) s

# %%
nombre = input('Ingresa tu nombre:')
print ('Hola, ', nombre)
# Out:
# Ingresa tu nombre:Luis
# Hola,  Luis

# %% [markdown]
# # Tipos de datos

# %% [markdown]
# ![Tipos_Datos_Python9.png](data:image/png;base64,...)

# %% [markdown]
# # Variables

# %%
precio = 1000
apellidos = 'Luna Zabala'
nota = 78
print ('El precio es:',precio,',','Los apellidos son:',apellidos,',','La nota es:',nota)
# Out:
# El precio es: 1000 , Los apellidos son: Luna Zabala , La nota es:  78

# %% [markdown]
# # Operaciones

# %%
multiplicacion = 8*4
costo = (10*5)-5
cantidad = 50/4
print ('La Multi es:',multiplicacion,',','El costo es:',costo,',','La cantidad es:',cantidad)
# Out:
# La Multi es: 32 , El costo es: 45 , La cantidad es: 12.5

# %% [markdown]
# ![operador_relacionados.png](data:image/png;base64,...)

# %%
7<5
9==3
2<12
88>=4

# %% [markdown]
# ![operador_logicos.png](data:image/png;base64,...)

# %%
(5<3) AND (4==7)
(1<7) OR (3==3)
NOT(6==7)
True AND False

# %% [markdown]
# ![operadores_operaciones.png](data:image/png;base64,...)
